# %% [markdown]
# # ¿Cómo crece una población?
#
#
# > El modelo más simple de crecimiento poblacional de organismos es $\frac{dx}{dt}=rx$, donde $x(t)$ es la población en el tiempo $t$ y $r>0$ es la tasa de crecimiento.
#
# > Este modelo predice crecimiento exponencial $x(t)=x_0e^{rt}$ (solución de la ecuación diferencial) donde $x_0=x(0)$ es la población inicial. ¿Es esto válido?
# - Recordar que $\lim_{t\to\infty}x(t)=x_0\lim_{t\to\infty}e^{rt}=\infty$.
# - Este modelo no tiene en cuenta entonces sobrepoblación ni recursos limitados.
#
# > En realidad la tasa de crecimiento no es una constante, sino que depende de la población $\frac{dx}{dt}=\mu(x)x$. Cuando $x$ es pequeña $\mu(x)\approx r$, como antes, pero cuando $x>1$ y $\mu(x)<0$: la tasa de muerte es mayor a la tasa de nacimiento. Una forma matemática conveniente de modelar lo anterior es con una tasa de crecimiento $\mu(x)$ decreciendo linealmente con $x$.
#
# Referencia:
# - Strogatz, Steven. *NONLINEAR DYNAMICS AND CHAOS*, ISBN: 9780813349107, (eBook disponible en biblioteca).

# %% [markdown]
# <img style="float: center;" src="./poblacion.jpg" width="450px" height="250px" />

# %% [markdown]
# ## Ecuación Logística
# Primero, veamos como luce $\mu(x)$ con decrecimiento lineal respecto a la población $x$.
#
# Como queremos que $\mu(0)=r$ y $\mu(1)=0$, la línea recta que conecta estos puntos es... (graficar)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-0.1,1.1,100)
def mu(x,r):
    return r*(1-x)
plt.plot(x,mu(x,0.01))
plt.plot([-0.1,1.1],[0,0],'k')
plt.plot([0,0],[-0.001,0.011],'k')
plt.grid()

# %% [markdown]
# ___
# Entonces, con esta elección de $\mu(x)=r(1-x)$, obtenemos la llamada **ecuación lógistica**, publicada por Pierre Verhulst en 1838.
#
# $$\frac{dx}{dt} = r\; x\; (1- x)$$

# %% [markdown]
# **Solución a la ecuación diferencial**
#
# La ecuación diferencial inicial tiene *solución analítica*,
# $$ x(t) = \frac{1}{1+ \left(\frac{1}{x_{0}}- 1\right) e^{-rt}}.$$

# %%
def sol(t,r,x0):
    return 1/(1+(1/x0-1)*np.exp(-r*t))

# %%
t=np.linspace(0,100,500)
x=sol(t,0.1,0.2)

plt.plot(t,x)
plt.grid()

# %% [markdown]
# Graficamos varias curvas de la solución analítica para $r = \left[-1, 1\right]$.

# %%
r=np.linspace(-1,1,10) # Límite máximo de variación poblacional "anual"
x0=0.2
t=np.linspace(0,50,500)
plt.figure(figsize=(10,7))
for r_i in r:
    x=sol(t,r_i,x0)
    plt.plot(t,x,label='$r=$'+str(round(r_i,2)))
plt.legend(loc='center left',bbox_to_anchor=(1.01,0.5))
plt.xlabel('Años')
plt.ylabel('Porcentaje de población')
plt.grid()

# %% [markdown]
# Como podemos ver, la solución a está ecuación en el continuo nos puede ganantizar la extinción o bien un crecimiento descomunal, dependiendo del valor asignado a $r$.

# %% [markdown]
# *Numéricamente*, ¿cómo resolveríamos esta ecuación?

# %%
from scipy.integrate import solve_ivp,odeint

# %%
solve_ivp?

# %%
odeint?

# %%
# Definimos la función de la derivada dx/dt
# Para la función odeint
#
def fun(x,t,r):
    return r*x*(1-x)

# %%
t=np.linspace(0,50,500) # Años
x0=0.2
r=0.2 # Tasa máxima de crecimiento anual
x=odeint(fun,x0,t,args=(r,))
x=x[:,0] # Tomar todos los valores de la columna 0
x
# Out:
# array([0.2       , 0.2032257 , 0.20649   , 0.20979292, 0.21313449,
#        0.21651469, 0.21993351, 0.22339091, 0.22688686, 0.23042129,
#        0.23399414, 0.23760523, 0.24125454, 0.2449419 , 0.24866713,
#        0.25243008, 0.25623054, 0.26006833, 0.2639432 , 0.2678549 ,
#        0.27180317, 0.27578772, 0.27980824, 0.28386439, 0.28795583,
#        0.29208219, 0.29624308, 0.30043809, 0.30466678, 0.30892871,
#        0.31322341, 0.31755037, 0.32190909, 0.32629903, 0.33071964,
#        0.33517035, 0.33965056, 0.34415965, 0.34869699, 0.35326193,
#        0.35785381, 0.36247191, 0.36711554, 0.37178397, 0.37647644,
#        0.38119221, 0.38593048, 0.39069047, 0.39547135, 0.40027231,
#        0.4050925 , 0.40993105, 0.4147871 , 0.41965977, 0.42454816,
#        0.42945134, 0.43436841, 0.43929843, 0.44424047, 0.44919355,
#        0.45415673, 0.45912904, 0.4641095 , 0.46909713, 0.47409094,
#        0.47908994, 0.48409313, 0.48909951, 0.49410807, 0.49911783,
#        0.50412775, 0.50913685, 0.51414412, 0.51914854, 0.52414913,
#        0.52914489, 0.53413481, 0.5391179 , 0.54409319, 0.5490597 ,
#        0.55401645, 0.55896248, 0.56389683, 0.56881856, 0.57372673,
#        0.57862042, 0.58349871, 0.58836071, 0.59320553, 0.59803227,
#        0.60284009, 0.60762814, 0.61239558, 0.61714159, 0.62186536,
#        0.62656613, 0.63124311, 0.63589555, 0.64052272, 0.6451239 ,
#        0.6496984 , 0.65424553, 0.65876465, 0.66325509, 0.66771625,
#        0.67214753, 0.67654834, 0.68091811, 0.68525632, 0.68956243,
#        0.69383595, 0.6980764 , 0.70228333, 0.70645628, 0.71059485,
#        0.71469863, 0.71876726, 0.72280036, 0.72679761, 0.73075869,
#        0.73468331, 0.73857118, 0.74242206, 0.7462357 , 0.75001189,
#        0.75375043, 0.75745114, 0.76111386, 0.76473845, 0.76832479,
#        0.77187276, 0.77538229, 0.77885329, 0.78228571, 0.78567952,
#        0.78903469, 0.79235122, 0.79562912, 0.79886841, 0.80206912,
#        0.80523132, 0.80835508, 0.81144046, 0.81448757, 0.81749651,
#        0.82046741, 0.82340039, 0.8262956 , 0.8291532 , 0.83197335,
#        0.83475622, 0.83750201, 0.8402109 , 0.84288311, 0.84551885,
#        0.84811834, 0.85068181, 0.85320949, 0.85570165, 0.85815853,
#        0.86058039, 0.8629675 , 0.86532014, 0.86763857, 0.8699231 ,
#        0.87217401, 0.87439159, 0.87657615, 0.87872798, 0.8808474 ,
#        0.88293471, 0.88499023, 0.88701428, 0.88900717, 0.89096923,
#        0.89290079, 0.89480217, 0.89667369, 0.8985157 , 0.90032852,
#        0.90211248, 0.90386793, 0.90559519, 0.9072946 , 0.90896649,
#        0.9106112 , 0.91222906, 0.91382041, 0.91538559, 0.91692493,
#        0.91843875, 0.9199274 , 0.92139121, 0.9228305 , 0.9242456 ,
#        0.92563685, 0.92700456, 0.92834906, 0.92967068, 0.93096973,
#        0.93224654, 0.93350142, 0.93473468, 0.93594664, 0.93713761,
#        0.93830789, 0.9394578 , 0.94058763, 0.94169768, 0.94278825,
#        0.94385964, 0.94491214, 0.94594604, 0.94696162, 0.94795917,
#        0.94893897, 0.9499013 , 0.95084643, 0.95177464, 0.95268619,
#        0.95358135, 0.95446038, 0.95532355, 0.95617111, 0.95700331,
#        0.95782041, 0.95862265, 0.95941028, 0.96018354, 0.96094267,
#        0.9616879 , 0.96241947, 0.9631376 , 0.96384253, 0.96453448,
#        0.96521366, 0.96588029, 0.96653459, 0.96717677, 0.96780704,
#        0.9684256 , 0.96903266, 0.96962841, 0.97021305, 0.97078678,
#        0.97134978, 0.97190225, 0.97244436, 0.97297631, 0.97349827,
#        0.97401041, 0.97451292, 0.97500596, 0.9754897 , 0.97596431,
#        0.97642996, 0.97688679, 0.97733498, 0.97777467, 0.97820603,
#        0.97862919, 0.97904432, 0.97945155, 0.97985103, 0.9802429 ,
#        0.98062729, 0.98100436, 0.98137423, 0.98173702, 0.98209288,
#        0.98244193, 0.9827843 , 0.9831201 , 0.98344947, 0.98377251,
#        0.98408935, 0.98440011, 0.98470488, 0.9850038 , 0.98529696,
#        0.98558447, 0.98586644, 0.98614297, 0.98641417, 0.98668013,
#        0.98694095, 0.98719674, 0.98744757, 0.98769356, 0.98793478,
#        0.98817133, 0.98840329, 0.98863076, 0.98885382, 0.98907255,
#        0.98928704, 0.98949736, 0.98970359, 0.98990581, 0.99010411,
#        0.99029854, 0.9904892 , 0.99067614, 0.99085944, 0.99103917,
#        0.99121539, 0.99138818, 0.9915576 , 0.99172372, 0.9918866 ,
#        0.99204629, 0.99220287, 0.99235638, 0.9925069 , 0.99265448,
#        0.99279917, 0.99294103, 0.99308011, 0.99321648, 0.99335017,
#        0.99348125, 0.99360976, 0.99373575, 0.99385927, 0.99398038,
#        0.99409911, 0.99421551, 0.99432962, 0.9944415 , 0.99455118,
#        0.99465872, 0.99476413, 0.99486748, 0.9949688 , 0.99506813,
#        0.99516551, 0.99526098, 0.99535457, 0.99544632, 0.99553626,
#        0.99562444, 0.99571088, 0.99579562, 0.99587869, 0.99596013,
#        0.99603997, 0.99611823, 0.99619495, 0.99627017, 0.9963439 ,
#        0.99641618, 0.99648703, 0.99655649, 0.99662458, 0.99669133,
#        0.99675677, 0.99682091, 0.99688379, 0.99694543, 0.99700585,
#        0.99706508, 0.99712314, 0.99718006, 0.99723586, 0.99729055,
#        0.99734417, 0.99739672, 0.99744824, 0.99749874, 0.99754825,
#        0.99759677, 0.99764434, 0.99769097, 0.99773668, 0.99778149,
#        0.99782541, 0.99786846, 0.99791067, 0.99795203, 0.99799259,
#        0.99803234, 0.9980713 , 0.99810949, 0.99814693, 0.99818363,
#        0.99821961, 0.99825487, 0.99828943, 0.99832332, 0.99835653,
#        0.99838908, 0.99842099, 0.99845227, 0.99848294, 0.99851299,
#        0.99854245, 0.99857133, 0.99859963, 0.99862738, 0.99865458,
#        0.99868124, 0.99870737, 0.99873298, 0.99875809, 0.9987827 ,
#        0.99880682, 0.99883047, 0.99885365, 0.99887636, 0.99889863,
#        0.99892046, 0.99894186, 0.99896283, 0.99898339, 0.99900354,
#        0.99902329, 0.99904265, 0.99906163, 0.99908023, 0.99909846,
#        0.99911633, 0.99913385, 0.99915102, 0.99916785, 0.99918435,
#        0.99920052, 0.99921637, 0.9992319 , 0.99924713, 0.99926206,
#        0.99927669, 0.99929103, 0.99930508, 0.99931886, 0.99933237,
#        0.9993456 , 0.99935858, 0.9993713 , 0.99938376, 0.99939598,
#        0.99940796, 0.9994197 , 0.99943121, 0.99944249, 0.99945354,
#        0.99946438, 0.999475  , 0.99948541, 0.99949561, 0.99950562,
#        0.99951542, 0.99952503, 0.99953445, 0.99954368, 0.99955273,
#        0.9995616 , 0.9995703 , 0.99957882, 0.99958717, 0.99959536,
#        0.99960338, 0.99961125, 0.99961896, 0.99962652, 0.99963393,
#        0.99964119, 0.9996483 , 0.99965528, 0.99966212, 0.99966882,
#        0.99967539, 0.99968182, 0.99968814, 0.99969432, 0.99970038,
#        0.99970633, 0.99971215, 0.99971786, 0.99972346, 0.99972894,
#        0.99973432, 0.99973959, 0.99974475, 0.99974982, 0.99975478,
#        0.99975964, 0.99976441, 0.99976909, 0.99977367, 0.99977816,
#        0.99978256, 0.99978687, 0.9997911 , 0.99979524, 0.9997993 ,
#        0.99980328, 0.99980719, 0.99981101, 0.99981476, 0.99981844])

# %%
plt.plot(t,sol(t,r,x0),lw=4,label='Solución analítica')
plt.plot(t,x,'y',lw=1,label='Solución numérica')
plt.xlabel('Años')
plt.ylabel('Porcentaje de población')
plt.legend(loc='best')
plt.grid()

# %%
# Definimos la función de la derivada dx/dt
# Para la función solve_ivp
#
def f(t,x):
    return r*x*(1-x)    # 'r' debe estar definida fuera de la función

# %%
solve_ivp?

# %%
tspan=[0,50]
x0=np.array([0.2])
sol_x=solve_ivp(f,tspan,x0,max_step=0.1) # ,dense_output=True)
#sol_x

# %%
plt.plot(sol_x.t,sol(sol_x.t,r,x0),lw=4,label='Solución analítica')
plt.plot(sol_x.t,sol_x.y[0,:],'y',lw=1,label='Solución numérica')
plt.legend(loc='best')
plt.xlabel('Años')
plt.ylabel('Porcentaje de población')
plt.grid()

# %% [markdown]
# ### ¿Qué tan buena es la aproximación de la solución numérica?
# Hay ecuaciones diferenciales ordinarias no lineales para las cuales es imposible obtener la solución exacta. En estos casos, se evalúa una solución aproximada de forma numérica.
#
# Para el caso anterior fue posible obtener la solución exacta, lo cual nos permite comparar ambas soluciones y evaluar qué tan buena es la aproximación que nos brinda la solución numérica.
#
# Primero veamos esto gráficamente

# %%
e_odeint=sol(t,r,x0)-x
e_solve_ivp=sol(sol_x.t,r,x0)-sol_x.y[0,:]

plt.plot(t,e_odeint,label='Error de odeint')
plt.plot(sol_x.t,e_solve_ivp*10**6,label='Error de solve_ivp $(x10^{-6})$')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# Gráficamente vemos que la solución numérica está cerca (coincide) con la solución exacta. Sin embargo, con esta gráfica no podemos visualizar qué tan cerca están una solución de la otra. ¿Qué tal si evaluamos el error?

# %% [markdown]
# Entonces, **cualitativamente** ya vimos que la solución numérica es *suficientemente buena*. De todas maneras, es siempre bueno cuantificar *qué tan buena* es la aproximación. Varias formas:
# - <font color=blue>Norma del error</font>: tenemos el error de aproximación en ciertos puntos (especificados por el vector de tiempo). Este error es entonces un vector y le podemos tomar su norma 2
#
# $$||e||_2=\sqrt{e[0]^2+\dots+e[n-1]^2}$$

# %%
np.linalg.norm(e_odeint),np.linalg.norm(e_solve_ivp)
# Out:
# (6.059264235440352e-07, 3.042704429347355e-13)

# %% [markdown]
# - <font color=blue>Error cuadrático medio</font>: otra forma de cuantificar es con el error cuadrático medio
#
# $$e_{ms}=\frac{e[0]^2+\dots+e[n-1]^2}{n}$$

# %%
np.mean(e_odeint**2),np.mean(e_solve_ivp**2)
# Out:
# (7.342936614977311e-16, 1.847914220433136e-28)

# %% [markdown]
# - <font color=blue>Integral del error cuadrático</font>: evalúa la acumulación de error cuadrático. Se puede leevar a cabo con la siguiente aproximación rectangular de la integral
#
# $$e_{is}=\int_{0}^{t_f}e(t)^2\text{d}t\approx \left(e[0]^2+\dots+e[n-1]^2\right)h$$
#
# donde $h$ es el tamaño de paso del vector de tiempo.

# %%
np.sum(e_odeint**2)*(t[1]-t[0])
# Out:
# 3.6788259594074706e-14

# %%
np.sum(e_solve_ivp**2)*(sol_x.t[1]-sol_x.t[0])
# Out:
# 9.258050244370011e-27

# %% [markdown]
# ### Comentarios del modelo logístico
# El modelo no se debe tomar literalmente. Más bien se debe interpretar metefóricamente como que la población tiene una tendencia a crecer hasta su tope, o bien, desaparecer.
#
# La ecuación logística fue probada en experimentos de laboratorio para colonias de bacterias en condiciones de clima constante, abastecimiento de comida y ausencia de predadores. Los experimentos mostraron que la ecuación predecía muy bien el comportamiento real.
#
# Por otra parte, la predicción no resultó tan buena para moscas que se alimentan de frutas, escarabajos y otros organismos con ciclos de vida complejos. En esos casos se observaron fluctuaciones (oscilaciones) inmensas de la población.

# %% [markdown]
# ___
# ## Mapa logístico
# > La ecuación logística (curva de crecimiento logístico) es un modelo del crecimiento continuo en el tiempo. Una modificación de la ecuación continua a una ecuación de recurrencia discreta conocida como **mapa logistico** es muy usada.
#
# Referencia:
# - https://es.wikipedia.org/wiki/Aplicación_log%C3%ADstica
# - https://en.wikipedia.org/wiki/Logistic_map
#
# > Si reemplazamos la ecuación logísitica por la ecuación a diferencias:
#
# > $$x_{n+1} = r\; x_{n}(1- x_{n}),$$
#
# > donde $r$ es la razón de crecimiento máximo de la población y $x_{n}$ es la n-ésima iteración. Entonces, lo que tenemos que programar es la siguiente relación recursiva
#
# > $$x_{n+1}^{(r)} = f_r(x_n^{(r)}) = rx_n^{(r)}(1-x_n^{(r)})$$

# %% [markdown]
# El siguiente `gif` muestra las primeras 63 iteraciones de la anterior ecuación para diferentes valores de $r$ variando entre 2 y 4.
#
# <img style="float: center;" src="https://upload.wikimedia.org/wikipedia/commons/1/1f/Logistic_map_animation.gif" width="800px" height="400px" />
#
# Tomado de https://upload.wikimedia.org/wikipedia/commons/1/1f/Logistic_map_animation.gif.
#
# Note que:
# - Para $2<r<3$ las soluciones se estabilizan en un valor de equilibrio.
# - Para $3<r<1+\sqrt{6}\approx 3.44949$ las soluciones oscilan entre dos valores.
# - Para $3.44949<r<3.54409$ las soluciones oscilan entre cuatro valores.
# - Para $r>3.54409$ las soluciones exhiben un comportamiento **caótico**.
#
# <font color=red> Caos: comportamiento determinista aperiódico muy sensible a las condiciones iniciales. Es decir, pequeñas variaciones en dichas condiciones iniciales pueden implicar grandes diferencias en el comportamiento futuro</font>

# %% [markdown]
# **¿Cómo podemos capturar este comportamiento en una sola gráfica?**
