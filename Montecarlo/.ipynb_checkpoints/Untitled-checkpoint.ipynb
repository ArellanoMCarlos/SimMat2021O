# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
def rendija(x,y):
    dx=0.1
    return ((x>=0.2) & (x<=0.2+dx)&(y>=0.2) & (y<=0.8))|((x>=0.6) & (x<=0.6+dx)&(y>=0.2) & (y<=0.8))

# %%
plt.figure(figsize=(6,6))
plt.plot([0,1,1,0,0],[0,0,1,1,0])
x=np.random.uniform(0,1,300)
y=np.random.uniform(0,1,300)
X,Y=np.meshgrid(x,y)
plt.scatter(X,Y,c=~rendija(X,Y),cmap='gray',s=1)

# %%
def FO(x):
    A=1
    t=1
    v=2e6
    w=4e6
    return A*np.exp(1j*w*(t-x/v))
FO(0.6)
# Out:
# 1.0
